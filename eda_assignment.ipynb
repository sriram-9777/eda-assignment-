# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Student Depression Dataset.csv')
df1 = pd.read_csv('/content/Student Mental health.csv')
df2 = pd.read_csv('/content/covid_19_clean_complete.csv')
df3 = pd.read_csv('/content/study_performance.csv')
df4 =pd.read_csv('/content/Groceries_dataset.csv')

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df1.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df2.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df3.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df4.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df.shape
# Out:
# (27901, 18)

# %%
df1.shape
# Out:
# (101, 11)

# %%
df2.shape
# Out:
# (49068, 10)

# %%
df3.shape
# Out:
# (1000, 8)

# %%
df4.shape
# Out:
# (38765, 3)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['Member_number', 'Date', 'itemDescription'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
df['Gender'].dtypes
# Out:
# dtype('O')

# %%
df['Gender'].dtypes=='O'
# Out:
# True

# %%
df1['Timestamp'].dtypes
# Out:
# dtype('O')

# %%
df1['Timestamp'].dtypes=='O'
# Out:
# True

# %%
df2['Date'].dtypes
# Out:
# dtype('O')

# %%
df2['Date'].dtypes=='O'
# Out:
# True

# %%
df3['parental_level_of_education'].dtypes
# Out:
# dtype('O')

# %%
df3['parental_level_of_education'].dtypes=='O'
# Out:
# True

# %%
df4['itemDescription'].dtypes
# Out:
# dtype('O')

# %%
df4['itemDescription'].dtypes=='O'
# Out:
# True

# %%
cat_col=[fea for fea in df.columns if df[fea].dtype == 'O']

# %%
df[cat_col]
# Out:
#        Gender           City Profession     Sleep Duration Dietary Habits  \
# 0        Male  Visakhapatnam    Student          5-6 hours        Healthy
# 1      Female      Bangalore    Student          5-6 hours       Moderate
# 2        Male       Srinagar    Student  Less than 5 hours        Healthy
# 3      Female       Varanasi    Student          7-8 hours       Moderate
# 4      Female         Jaipur    Student          5-6 hours       Moderate
# ...       ...            ...        ...                ...            ...
# 27896  Female          Surat    Student          5-6 hours      Unhealthy
# 27897    Male       Ludhiana    Student  Less than 5 hours        Healthy
# 27898    Male      Faridabad    Student          5-6 hours      Unhealthy
# 27899  Female       Ludhiana    Student  Less than 5 hours        Healthy
# 27900    Male          Patna    Student  Less than 5 hours        Healthy
#
#          Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
bat_col=[fea for fea in df1.columns if df1[fea].dtype == 'O']

# %%
df1[bat_col]
# Out:
#                Timestamp Choose your gender What is your course?  \
# 0         8/7/2020 12:02             Female          Engineering
# 1         8/7/2020 12:04               Male    Islamic education
# 2         8/7/2020 12:05               Male                  BIT
# 3         8/7/2020 12:06             Female                 Laws
# 4         8/7/2020 12:13               Male         Mathemathics
# ..                   ...                ...                  ...
# 96   13/07/2020 19:56:49             Female                  BCS
# 97   13/07/2020 21:21:42               Male          Engineering
# 98   13/07/2020 21:22:56             Female             Nursing
# 99   13/07/2020 21:23:57             Female     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# ...

# %%
cat_col=[fea for fea in df2.columns if df2[fea].dtype == 'O']

# %%
df2[cat_col]
# Out:
#       Province/State         Country/Region        Date             WHO Region
# 0                NaN            Afghanistan  2020-01-22  Eastern Mediterranean
# 1                NaN                Albania  2020-01-22                 Europe
# 2                NaN                Algeria  2020-01-22                 Africa
# 3                NaN                Andorra  2020-01-22                 Europe
# 4                NaN                 Angola  2020-01-22                 Africa
# ...              ...                    ...         ...                    ...
# 49063            NaN  Sao Tome and Principe  2020-07-27                 Africa
# 49064            NaN                  Yemen  2020-07-27  Eastern Mediterranean
# 49065            NaN                Comoros  2020-07-27                 Africa
# 49066            NaN             Tajikistan  2020-07-27                 Europe
# 49067            NaN                Lesotho  2020-07-27                 Africa
#
# ...

# %%
dee_col=[fea for fea in df3.columns if df3[fea].dtype == 'O']

# %%
df3[dee_col]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
aee_col=[fea for fea in df4.columns if df4[fea].dtype == 'O']

# %%
df4[aee_col]
# Out:
#              Date        itemDescription
# 0      21-07-2015         tropical fruit
# 1      05-01-2015             whole milk
# 2      19-09-2015              pip fruit
# 3      12-12-2015       other vegetables
# 4      01-02-2015             whole milk
# ...           ...                    ...
# 38760  08-10-2014          sliced cheese
# 38761  23-02-2014                  candy
# 38762  16-04-2014               cake bar
# 38763  03-12-2014  fruit/vegetable juice
# 38764  26-12-2014               cat food
#
# [38765 rows x 2 columns]

# %%
num_col=[fea for fea in df.columns if df[fea].dtype != 'O']

# %%
df[num_col]
# Out:
#            id   Age  Academic Pressure  Work Pressure  CGPA  \
# 0           2  33.0                5.0            0.0  8.97
# 1           8  24.0                2.0            0.0  5.90
# 2          26  31.0                3.0            0.0  7.03
# 3          30  28.0                3.0            0.0  5.59
# 4          32  25.0                4.0            0.0  8.13
# ...       ...   ...                ...            ...   ...
# 27896  140685  27.0                5.0            0.0  5.75
# 27897  140686  27.0                2.0            0.0  9.40
# 27898  140689  31.0                3.0            0.0  6.61
# 27899  140690  18.0                5.0            0.0  6.88
# 27900  140699  27.0                4.0            0.0  9.24
#
#        Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# 0                     2.0               0.0               3.0
# 1                     5.0               0.0               3.0
# ...

# %%
qwq=[fea for fea in df1.columns if df1[fea].dtype != 'O']

# %%
df1[qwq]
# Out:
#       Age
# 0    18.0
# 1    21.0
# 2    19.0
# 3    22.0
# 4    23.0
# ..    ...
# 96   21.0
# 97   18.0
# 98   19.0
# 99   23.0
# 100  20.0
#
# [101 rows x 1 columns]

# %%
wer=[fea for fea in df2.columns if df2[fea].dtype != 'O']

# %%
df2[wer]
# Out:
#              Lat       Long  Confirmed  Deaths  Recovered  Active
# 0      33.939110  67.709953          0       0          0       0
# 1      41.153300  20.168300          0       0          0       0
# 2      28.033900   1.659600          0       0          0       0
# 3      42.506300   1.521800          0       0          0       0
# 4     -11.202700  17.873900          0       0          0       0
# ...          ...        ...        ...     ...        ...     ...
# 49063   0.186400   6.613100        865      14        734     117
# 49064  15.552727  48.516388       1691     483        833     375
# 49065 -11.645500  43.333300        354       7        328      19
# 49066  38.861000  71.276100       7235      60       6028    1147
# 49067 -29.610000  28.233600        505      12        128     365
#
# [49068 rows x 6 columns]

# %%
ert = [fea for fea in df3.columns if df3[fea].dtype != 'O']

# %%
df3[ert]
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
asd = [fea for fea in df4.columns if df4[fea].dtype != 'O']

# %%
df4[asd]
# Out:
#        Member_number
# 0               1808
# 1               2552
# 2               2300
# 3               1187
# 4               3037
# ...              ...
# 38760           4471
# 38761           2022
# 38762           1097
# 38763           1510
# 38764           1521
#
# [38765 rows x 1 columns]

# %%
df.memory_usage()
# Out:
# Index                                       132
# id                                       223208
# Gender                                   223208
# Age                                      223208
# City                                     223208
# Profession                               223208
# Academic Pressure                        223208
# Work Pressure                            223208
# CGPA                                     223208
# Study Satisfaction                       223208
# Job Satisfaction                         223208
# Sleep Duration                           223208
# Dietary Habits                           223208
# Degree                                   223208
# Have you ever had suicidal thoughts ?    223208
# Work/Study Hours                         223208
# Financial Stress                         223208
# Family History of Mental Illness         223208
# Depression                               223208
# dtype: int64

# %%
df1.memory_usage()
# Out:
# Index                                           132
# Timestamp                                       808
# Choose your gender                              808
# Age                                             808
# What is your course?                            808
# Your current year of Study                      808
# What is your CGPA?                              808
# Marital status                                  808
# Do you have Depression?                         808
# Do you have Anxiety?                            808
# Do you have Panic attack?                       808
# Did you seek any specialist for a treatment?    808
# dtype: int64

# %%
df2.memory_usage()
# Out:
# Index                132
# Province/State    392544
# Country/Region    392544
# Lat               392544
# Long              392544
# Date              392544
# Confirmed         392544
# Deaths            392544
# Recovered         392544
# Active            392544
# WHO Region        392544
# dtype: int64

# %%
df3.memory_usage()
# Out:
# Index                           132
# gender                         8000
# race_ethnicity                 8000
# parental_level_of_education    8000
# lunch                          8000
# test_preparation_course        8000
# math_score                     8000
# reading_score                  8000
# writing_score                  8000
# dtype: int64

# %%
df4.memory_usage()
# Out:
# Index                 132
# Member_number      310120
# Date               310120
# itemDescription    310120
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3

# %%
df1.isnull().sum().sum()
# Out:
# 1

# %%
df2.isnull().sum().sum()
# Out:
# 34404

# %%
df3.isnull().sum().sum()
# Out:
# 0

# %%
df4.isnull().sum().sum()
# Out:
# 0

# %%
numeric_data = df.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#                           id       Age  Academic Pressure  Work Pressure  \
# id                  1.000000  0.003783           0.005172       0.001261
# Age                 0.003783  1.000000          -0.075803       0.002015
# Academic Pressure   0.005172 -0.075803           1.000000      -0.022231
# Work Pressure       0.001261  0.002015          -0.022231       1.000000
# CGPA               -0.012324  0.005056          -0.022239      -0.050896
# Study Satisfaction  0.007794  0.009235          -0.110988      -0.021145
# Job Satisfaction    0.001931 -0.000432          -0.024945       0.770652
# Work/Study Hours   -0.004466 -0.032928           0.095970      -0.005468
# Financial Stress    0.000783 -0.095026           0.151706       0.001883
# Depression          0.000923 -0.226422           0.474835      -0.003351
#
#                         CGPA  Study Satisfaction  Job Satisfaction  \
# id                 -0.012324            0.007794          0.001931
# ...

# %%
numeric_data = df.select_dtypes(include=['number'])
covariance_matrix = numeric_data.cov()
print(covariance_matrix)
# Out:
#                               id         Age  Academic Pressure  \
# id                  1.651705e+09  754.153076         290.381049
# Age                 7.541531e+02   24.065769          -0.513723
# Academic Pressure   2.903810e+02   -0.513723           1.908445
# Work Pressure       2.254058e+00    0.000435          -0.001351
# CGPA               -7.366278e+02    0.036477          -0.045183
# Study Satisfaction  4.311282e+02    0.061668          -0.208700
# Job Satisfaction    3.483124e+00   -0.000094          -0.001530
# Work/Study Hours   -6.728855e+02   -0.598913           0.491559
# Financial Stress    4.575481e+01   -0.670041           0.301233
# Depression          1.848258e+01   -0.547208           0.323159
#
#                     Work Pressure        CGPA  Study Satisfaction  \
# id                       2.254058 -736.627752          431.128213
# Age                      0.000435    0.036477            0.061668
# ...

# %%
numeric_data.skew()
# Out:
# id                     -0.005380
# Age                     0.132239
# Academic Pressure      -0.135165
# Work Pressure         108.594361
# CGPA                   -0.113063
# Study Satisfaction      0.010423
# Job Satisfaction       74.105663
# Work/Study Hours       -0.454769
# Financial Stress       -0.130304
# Depression             -0.347126
# dtype: float64

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
q1 = df['Age'].quantile(0.25)
q3 = df['Age'].quantile(0.75)
iqr = q3 - q1

# %%
iqr
# Out:
# 9.0

# %%
upper_limit=q3+(1.5*iqr)
lower_limit=q1-(1.5*iqr)

# %%
upper_limit
# Out:
# 43.5

# %%
  lower_limit
# Out:
# 7.5

# %%
data_outlier=df[(df['Age']<upper_limit)]

# %%
data_num.drop(data_outlier.index)
# Out:
#            id   Age  Academic Pressure  Work Pressure  CGPA  \
# 2909    14768  58.0                4.0            0.0  8.58
# 3436    17213  49.0                3.0            0.0  6.47
# 4386    22004  51.0                2.0            0.0  8.26
# 5537    27918  44.0                1.0            0.0  6.83
# 9006    45393  46.0                1.0            0.0  6.10
# 9238    46602  59.0                1.0            0.0  8.14
# 13499   68441  54.0                5.0            0.0  9.60
# 13618   69032  48.0                3.0            0.0  7.48
# 14819   74887  56.0                3.0            0.0  7.94
# 18766   94978  46.0                3.0            0.0  6.83
# 25202  126970  48.0                3.0            0.0  5.32
# 27334  137827  48.0                1.0            0.0  8.92
#
#        Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# 2909                  1.0               0.0               4.0
# ...

# %%
df[df['Age']>upper_limit]
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 2909    14768  Female  58.0    Chennai    Student                4.0
# 3436    17213    Male  49.0     Nagpur    Student                3.0
# 4386    22004  Female  51.0     Bhopal    Student                2.0
# 5537    27918  Female  44.0   Srinagar    Student                1.0
# 9006    45393    Male  46.0     Nashik    Student                1.0
# 9238    46602    Male  59.0     Nashik    Student                1.0
# 13499   68441    Male  54.0       Agra    Student                5.0
# 13618   69032  Female  48.0  Ghaziabad    Student                3.0
# 14819   74887  Female  56.0   Ludhiana    Student                3.0
# 18766   94978  Female  46.0    Lucknow    Student                3.0
# 25202  126970  Female  48.0     Rajkot    Student                3.0
# 27334  137827  Female  48.0      Surat    Student                1.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df['Age'].quantile(1.00)
# Out:
# 59.0

# %%
df['Age'].min()
# Out:
# 18.0

# %%
df['Age'].max()
# Out:
# 59.0

# %%
df['Age'].unique()
# Out:
# array([33., 24., 31., 28., 25., 29., 30., 27., 19., 20., 23., 18., 21.,
#        22., 34., 32., 26., 39., 35., 42., 36., 58., 49., 38., 51., 44.,
#        43., 46., 59., 54., 48., 56., 37., 41.])

# %%
data_num.columns
# Out:
# Index(['id', 'Age', 'Academic Pressure', 'Work Pressure', 'CGPA',
#        'Study Satisfaction', 'Job Satisfaction', 'Work/Study Hours',
#        'Financial Stress', 'Depression'],
#       dtype='object')

# %%
def get_iqr(df, column_name, q1_range, q3_range):
    q1 = df[column_name].quantile(q1_range)
    q3 = df[column_name].quantile(q3_range)
    IQR = q3 - q1
    upper_fence = q3 + 1.5 * IQR
    lower_fence = q1 - 1.5 * IQR
    return iqr, upper_fence, lower_fence

# %%
def outlier_threshold(df,variable):
    q1=df[variable].quantile(0.25)
    q3=df[variable].quantile(0.75)
    iqr=q3-q1
    up_limit=q3+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %%
def replace_with_threshold(df,numeric_col):
    for variable in numeric_col:
        low_limit,upper_limit=outlier_threshold(data_num,variable)
        df.loc[df[variable]<low_limit,variable]=low_limit
        df.loc[df[variable]>upper_limit,variable]=upper_limit

# %%
replace_with_threshold(data_num,data_num.columns)

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
plt.bar('Age',0.8,label='Age')
plt.bar('Gender',0.8,label='Gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(data_num.corr())
plt.show()

# %%
sns.heatmap(data_num.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.pairplot(data_num)
plt.show()

# %%
sns.violinplot(data=data_num)
plt.show()

# %%
data_num=df[num_col]

# %%
data_num.head()
# Out:
#    id   Age  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0   2  33.0                5.0            0.0  8.97                 2.0
# 1   8  24.0                2.0            0.0  5.90                 5.0
# 2  26  31.0                3.0            0.0  7.03                 5.0
# 3  30  28.0                3.0            0.0  5.59                 2.0
# 4  32  25.0                4.0            0.0  8.13                 3.0
#
#    Job Satisfaction  Work/Study Hours  Financial Stress  Depression
# 0               0.0               3.0               1.0           1
# 1               0.0               3.0               2.0           0
# 2               0.0               9.0               1.0           0
# 3               0.0               4.0               5.0           1
# 4               0.0               1.0               1.0           0

# %%
sns.distplot(data_num['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
numeric_data =df1.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#      Age
# Age  1.0

# %%
numeric_data = df1.select_dtypes(include=['number'])
covariance_matrix = numeric_data.cov()
print(covariance_matrix)
# Out:
#           Age
# Age  6.231414

# %%
numeric_data.skew()
# Out:
# Age    0.377175
# dtype: float64

# %%
sns.distplot(df1['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df1
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df1.groupby('Marital status').mean(numeric_only = True)
# Out:
#                       Age
# Marital status
# No              20.416667
# Yes             21.125000

# %%
df1.groupby('Marital status').count()
# Out:
#                 Timestamp  Choose your gender  Age  What is your course?  \
# Marital status
# No                     85                  85   84                    85
# Yes                    16                  16   16                    16
#
#                 Your current year of Study  What is your CGPA?  \
# Marital status
# No                                      85                  85
# Yes                                     16                  16
#
#                 Do you have Depression?  Do you have Anxiety?  \
# Marital status
# No                                   85                    85
# Yes                                  16                    16
#
#                 Do you have Panic attack?  \
# Marital status
# No                                     85
# Yes                                    16
#
#                 Did you seek any specialist for a treatment?
# Marital status
# No                                                        85
# ...

# %%
data_num=df1[qwq]

# %%
data_num.head()
# Out:
#     Age
# 0  18.0
# 1  21.0
# 2  19.0
# 3  22.0
# 4  23.0

# %%
sns.boxplot(df1['Timestamp'])
# Out:
# <Axes: ylabel='Timestamp'>

# %%
q1 = df1['Age'].quantile(0.25)
q3 = df1['Age'].quantile(0.75)
iqr = q3 - q1

# %%
iqr
# Out:
# 5.0

# %%
upper_limit=q3+(1.5*iqr)

# %%
upper_limit
# Out:
# 30.5

# %%
lower_limit=q1-(1.5*iqr)

# %%
lower_limit
# Out:
# 10.5

# %%
data_outlier=df1[df1['Age']<lower_limit]

# %%
data_num.drop(data_outlier.index)
# Out:
#       Age
# 0    18.0
# 1    21.0
# 2    19.0
# 3    22.0
# 4    23.0
# ..    ...
# 96   21.0
# 97   18.0
# 98   19.0
# 99   23.0
# 100  20.0
#
# [101 rows x 1 columns]

# %%
df1[df1['Age']>upper_limit]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Choose your gender, Age, What is your course?, Your current year of Study, What is your CGPA?, Marital status, Do you have Depression?, Do you have Anxiety?, Do you have Panic attack?, Did you seek any specialist for a treatment?]
# Index: []

# %%
df1['Age'].quantile(1.00)
# Out:
# 24.0

# %%
df1['Age'].min()
# Out:
# 18.0

# %%
df1['Age'].max()
# Out:
# 24.0

# %%
df1['Age'].unique()
# Out:
# array([18., 21., 19., 22., 23., 20., 24., nan])

# %%
data_num.columns
# Out:
# Index(['Age'], dtype='object')

# %%
def get_iqr(df, column_name, q1_range, q3_range):
    q1 = df[column_name].quantile(q1_range)
    q3 = df[column_name].quantile(q3_range)
    IQR = q3 - q1
    upper_fence = q3 + 1.5 * IQR
    lower_fence = q1 - 1.5 * IQR
    return IQR, upper_fence, lower_fence

# %%
def outlier_threshold(df,variable):
    q1=df[variable].quantile(0.25)
    q3=df[variable].quantile(0.75)
    iqr=q3-q1
    up_limit=q3+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %%
def replace_with_threshold(data,numeric_col):
    for variable in numeric_col:
        low_limit,upper_limit=outlier_threshold(data_num,variable)
        df1.loc[df1[variable]<low_limit,variable]=low_limit
        df1.loc[df1[variable]>upper_limit,variable]=upper_limit

# %%
replace_with_threshold(data_num,data_num.columns)

# %%
sns.countplot(df1['Marital status'])
plt.show()

# %%
sns.countplot(df1['Timestamp'])
plt.show()

# %%
df=df1.groupby('Marital status').mean(numeric_only = True)

# %%
df
# Out:
#                       Age
# Marital status
# No              20.416667
# Yes             21.125000

# %%
plt.bar('Age',0.8,label='Age')
plt.bar('Gender',0.8,label='Gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_num.head()
# Out:
#     Age
# 0  18.0
# 1  21.0
# 2  19.0
# 3  22.0
# 4  23.0

# %%
data_num.corr()
# Out:
#      Age
# Age  1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(data_num.corr())
plt.show()

# %%
sns.heatmap(data_num.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.pairplot(data_num)
plt.show()

# %%
sns.violinplot(data=data_num)
plt.show()

# %%
numeric_data = df2.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#                 Lat      Long  Confirmed    Deaths  Recovered    Active
# Lat        1.000000 -0.127259   0.036665  0.070040   0.015329  0.044392
# Long      -0.127259  1.000000  -0.078911 -0.101340  -0.052391 -0.085688
# Confirmed  0.036665 -0.078911   1.000000  0.912361   0.895506  0.950255
# Deaths     0.070040 -0.101340   0.912361  1.000000   0.763090  0.891858
# Recovered  0.015329 -0.052391   0.895506  0.763090   1.000000  0.713088
# Active     0.044392 -0.085688   0.950255  0.891858   0.713088  1.000000

# %%
numeric_data = df2.select_dtypes(include=['number'])
covariance_matrix = numeric_data.cov()
print(covariance_matrix)
# Out:
#                      Lat           Long     Confirmed        Deaths  \
# Lat           622.518459    -223.667077  1.164558e+05  1.103308e+04
# Long         -223.667077    4962.179583 -7.076218e+05 -4.507056e+04
# Confirmed  116455.755075 -707621.764838  1.620534e+10  7.332833e+08
# Deaths      11033.080812  -45070.559239  7.332833e+08  3.986135e+07
# Recovered   20959.100283 -202244.974368  6.247200e+09  2.640216e+08
# Active      84463.573980 -460306.231231  9.224859e+09  4.294003e+08
#
#               Recovered        Active
# Lat        2.095910e+04  8.446357e+04
# Long      -2.022450e+05 -4.603062e+05
# Confirmed  6.247200e+09  9.224859e+09
# Deaths     2.640216e+08  4.294003e+08
# Recovered  3.003141e+09  2.980038e+09
# Active     2.980038e+09  5.815420e+09

# %%
numeric_data.skew()
# Out:
# Lat          -0.573083
# Long         -0.013375
# Confirmed    18.567593
# Deaths       13.740139
# Recovered    16.380959
# Active       22.306956
# dtype: float64

# %%
sns.distplot(df2['Confirmed'])
# Out:
# <Axes: xlabel='Confirmed', ylabel='Density'>

# %%
df2.groupby('Country/Region').count()
# Out:
#                     Province/State  Lat  Long  Date  Confirmed  Deaths  \
# Country/Region
# Afghanistan                      0  188   188   188        188     188
# Albania                          0  188   188   188        188     188
# Algeria                          0  188   188   188        188     188
# Andorra                          0  188   188   188        188     188
# Angola                           0  188   188   188        188     188
# ...                            ...  ...   ...   ...        ...     ...
# West Bank and Gaza               0  188   188   188        188     188
# Western Sahara                   0  188   188   188        188     188
# Yemen                            0  188   188   188        188     188
# Zambia                           0  188   188   188        188     188
# Zimbabwe                         0  188   188   188        188     188
#
#                     Recovered  Active  WHO Region
# Country/Region
# ...

# %%
df2.groupby('Country/Region').count()
# Out:
#                     Province/State  Lat  Long  Date  Confirmed  Deaths  \
# Country/Region
# Afghanistan                      0  188   188   188        188     188
# Albania                          0  188   188   188        188     188
# Algeria                          0  188   188   188        188     188
# Andorra                          0  188   188   188        188     188
# Angola                           0  188   188   188        188     188
# ...                            ...  ...   ...   ...        ...     ...
# West Bank and Gaza               0  188   188   188        188     188
# Western Sahara                   0  188   188   188        188     188
# Yemen                            0  188   188   188        188     188
# Zambia                           0  188   188   188        188     188
# Zimbabwe                         0  188   188   188        188     188
#
#                     Recovered  Active  WHO Region
# Country/Region
# ...

# %%
df2[df2['Confirmed']<30].count()
# Out:
# Province/State     5037
# Country/Region    18181
# Lat               18181
# Long              18181
# Date              18181
# Confirmed         18181
# Deaths            18181
# Recovered         18181
# Active            18181
# WHO Region        18181
# dtype: int64

# %%
data_num=df2[wer]

# %%
data_num.head()
# Out:
#         Lat       Long  Confirmed  Deaths  Recovered  Active
# 0  33.93911  67.709953          0       0          0       0
# 1  41.15330  20.168300          0       0          0       0
# 2  28.03390   1.659600          0       0          0       0
# 3  42.50630   1.521800          0       0          0       0
# 4 -11.20270  17.873900          0       0          0       0

# %%
sns.boxplot(df2['Confirmed'])
plt.show()

# %%
q1 = df2['Confirmed'].quantile(0.25)
q3 = df2['Confirmed'].quantile(0.75)
iqr = q3 - q1

# %%
iqr
# Out:
# 1514.25

# %%
upper_limit=q3+(1.5*iqr)

# %%
upper_limit
# Out:
# 3789.625

# %%
lower_limit=q1-(1.5*iqr)

# %%
lower_limit
# Out:
# -2267.375

# %%
data_outlier=df2[df2['Confirmed']<lower_limit]

# %%
data_num.drop(data_outlier.index)
# Out:
#              Lat       Long  Confirmed  Deaths  Recovered  Active
# 0      33.939110  67.709953          0       0          0       0
# 1      41.153300  20.168300          0       0          0       0
# 2      28.033900   1.659600          0       0          0       0
# 3      42.506300   1.521800          0       0          0       0
# 4     -11.202700  17.873900          0       0          0       0
# ...          ...        ...        ...     ...        ...     ...
# 49063   0.186400   6.613100        865      14        734     117
# 49064  15.552727  48.516388       1691     483        833     375
# 49065 -11.645500  43.333300        354       7        328      19
# 49066  38.861000  71.276100       7235      60       6028    1147
# 49067 -29.610000  28.233600        505      12        128     365
#
# [49068 rows x 6 columns]

# %%
df2[df2['Confirmed']>upper_limit]
# Out:
#       Province/State      Country/Region        Lat        Long        Date  \
# 2149           Hubei               China  30.975600  112.270700  2020-01-30
# 2410           Hubei               China  30.975600  112.270700  2020-01-31
# 2671           Hubei               China  30.975600  112.270700  2020-02-01
# 2932           Hubei               China  30.975600  112.270700  2020-02-02
# 3193           Hubei               China  30.975600  112.270700  2020-02-03
# ...              ...                 ...        ...         ...         ...
# 49032            NaN           Venezuela   6.423800  -66.589700  2020-07-27
# 49034            NaN              Zambia -13.133897   27.849332  2020-07-27
# 49044            NaN  West Bank and Gaza  31.952200   35.233200  2020-07-27
# 49050            NaN              Kosovo  42.602636   20.902977  2020-07-27
# 49066            NaN          Tajikistan  38.861000   71.276100  2020-07-27
#
# ...

# %%
df2['Confirmed'].quantile(1.00)
# Out:
# 4290259.0

# %%
df2['Confirmed'].min()
# Out:
# 0

# %%
df2['Confirmed'].max()
# Out:
# 4290259

# %%
df2['Confirmed'].unique()
# Out:
# array([   0,    1,   14, ..., 7413, 3664, 7235])

# %%
data_num.columns
# Out:
# Index(['Lat', 'Long', 'Confirmed', 'Deaths', 'Recovered', 'Active'], dtype='object')

# %%
def get_iqr(df, column_name, q1_range, q3_range):
    q1 = df[column_name].quantile(q1_range)
    q3 = df[column_name].quantile(q3_range)
    IQR = q3 - q1
    upper_fence = q3 + 1.5 * IQR
    lower_fence = q1 - 1.5 * IQR
    return IQR, upper_fence, lower_fence

# %%
def outlier_threshold(df,variable):
    q1=df[variable].quantile(0.25)
    q3=df[variable].quantile(0.75)
    iqr=q3-q1
    up_limit=q3+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %%
def replace_with_threshold(data,numeric_col):
    for variable in numeric_col:
        low_limit,upper_limit=outlier_threshold(data_num,variable)
        df2.loc[df2[variable]<low_limit,variable]=low_limit
        df2.loc[df2[variable]>upper_limit,variable]=upper_limit

# %%
replace_with_threshold(data_num,data_num.columns)

# %%
sns.countplot(df2['Date'])
plt.show()

# %%
df=df2.groupby('Date').mean(numeric_only = True)

# %%
df
# Out:
#                   Lat       Long    Confirmed     Deaths   Recovered  \
# Date
# 2020-01-22  21.473694  23.528236     2.126437   0.065134    0.107280
# 2020-01-23  21.473694  23.528236     2.505747   0.068966    0.114943
# 2020-01-24  21.473694  23.528236     3.605364   0.099617    0.137931
# 2020-01-25  21.473694  23.528236     5.494253   0.160920    0.149425
# 2020-01-26  21.473694  23.528236     8.114943   0.214559    0.199234
# ...               ...        ...          ...        ...         ...
# 2020-07-23  21.473694  23.528236  2018.522510  38.984674  916.038314
# 2020-07-24  21.473694  23.528236  2026.597701  39.141762  918.724138
# 2020-07-25  21.473694  23.528236  2032.892720  39.268199  920.620690
# 2020-07-26  21.473694  23.528236  2040.137931  39.371648  924.298851
# 2020-07-27  21.473694  23.528236  2047.669061  39.509579  927.153257
#
#                 Active
# Date
# 2020-01-22    1.954023
# 2020-01-23    2.321839
# 2020-01-24    3.367816
# 2020-01-25    5.183908
# ...

# %%
plt.bar('Confirmed',0.8,label='Confirmed')
plt.bar('Deaths',0.8,label='Deaths')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_num.head()
# Out:
#         Lat       Long  Confirmed  Deaths  Recovered  Active
# 0  33.93911  67.709953          0       0          0       0
# 1  41.15330  20.168300          0       0          0       0
# 2  28.03390   1.659600          0       0          0       0
# 3  42.50630   1.521800          0       0          0       0
# 4 -11.20270  17.873900          0       0          0       0

# %%
data_num.corr()
# Out:
#                 Lat      Long  Confirmed    Deaths  Recovered    Active
# Lat        1.000000 -0.127259   0.036665  0.070040   0.015329  0.044392
# Long      -0.127259  1.000000  -0.078911 -0.101340  -0.052391 -0.085688
# Confirmed  0.036665 -0.078911   1.000000  0.912361   0.895506  0.950255
# Deaths     0.070040 -0.101340   0.912361  1.000000   0.763090  0.891858
# Recovered  0.015329 -0.052391   0.895506  0.763090   1.000000  0.713088
# Active     0.044392 -0.085688   0.950255  0.891858   0.713088  1.000000

# %%
sns.heatmap(data_num.corr())
plt.show()

# %%
sns.heatmap(data_num.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.pairplot(data_num)
plt.show()

# %%
sns.violinplot(data=data_num)
plt.show()

# %%
numeric_data = df3.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#                math_score  reading_score  writing_score
# math_score       1.000000       0.817580       0.802642
# reading_score    0.817580       1.000000       0.954598
# writing_score    0.802642       0.954598       1.000000

# %%
numeric_data = df3.select_dtypes(include=['number'])
covariance_matrix = numeric_data.cov()
print(covariance_matrix)
# Out:
#                math_score  reading_score  writing_score
# math_score     229.918998     180.998958     184.939133
# reading_score  180.998958     213.165605     211.786661
# writing_score  184.939133     211.786661     230.907992

# %%
numeric_data.skew()
# Out:
# math_score      -0.278935
# reading_score   -0.259105
# writing_score   -0.289444
# dtype: float64

# %%
sns.distplot(df3['writing_score'])
# Out:
# <Axes: xlabel='writing_score', ylabel='Density'>

# %%
df3['averge'] =(df3['math_score']+df3['reading_score']+df3['writing_score'])/3

# %%
df3.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score     averge
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
df3.groupby('gender').mean(numeric_only = True)
# Out:
#         math_score  reading_score  writing_score     averge
# gender
# female   63.633205      72.608108      72.467181  69.569498
# male     68.728216      65.473029      63.311203  65.837483

# %%
df3.groupby('gender').count()
# Out:
#         race_ethnicity  parental_level_of_education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test_preparation_course  math_score  reading_score  writing_score  \
# gender
# female                      518         518            518            518
# male                        482         482            482            482
#
#         averge
# gender
# female     518
# male       482

# %%
df3[df3['math_score'] < 30].count()
# Out:
# gender                         14
# race_ethnicity                 14
# parental_level_of_education    14
# lunch                          14
# test_preparation_course        14
# math_score                     14
# reading_score                  14
# writing_score                  14
# averge                         14
# dtype: int64

# %%
data_num=df3[ert]

# %%
data_num.head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
sns.distplot(data_num['reading_score'])
plt.show()

# %%
sns.boxplot(df3['writing_score'])
plt.show()

# %%
q1 = df3['writing_score'].quantile(0.25)
q3 = df3['writing_score'].quantile(0.75)
iqr = q3 - q1

# %%
iqr
# Out:
# 21.25

# %%
upper_limit=q3+(1.5*iqr)

# %%
upper_limit
# Out:
# 110.875

# %%
lower_limit=q1-(1.5*iqr)

# %%
lower_limit
# Out:
# 25.875

# %%
data_outlier=df3[df3['math_score']<lower_limit]

# %%
data_num.drop(data_outlier.index)
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [993 rows x 3 columns]

# %%
df3[df3['math_score']>upper_limit]
# Out:
# Empty DataFrame
# Columns: [gender, race_ethnicity, parental_level_of_education, lunch, test_preparation_course, math_score, reading_score, writing_score, averge]
# Index: []

# %%
df3['math_score'].quantile(1.00)
# Out:
# 100.0

# %%
df3['math_score'].min()
# Out:
# 0

# %%
df3['math_score'].max()
# Out:
# 100

# %%
df3['math_score'].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %%
data_num.columns
# Out:
# Index(['math_score', 'reading_score', 'writing_score'], dtype='object')

# %%
def get_iqr(df, column_name, q1_range, q3_range):
    q1 = df[column_name].quantile(q1_range)
    q3 = df[column_name].quantile(q3_range)
    IQR = q3 - q1
    upper_fence = q3 + 1.5 * IQR
    lower_fence = q1 - 1.5 * IQR
    return IQR, upper_fence, lower_fence

# %%
def outlier_threshold(df,variable):
    q1=df[variable].quantile(0.25)
    q3=df[variable].quantile(0.75)
    iqr=q3-q1
    up_limit=q3+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %%
def replace_with_threshold(data,numeric_col):
    for variable in numeric_col:
        low_limit,upper_limit=outlier_threshold(data_num,variable)
        df3.loc[df3[variable]<low_limit,variable]=low_limit
        df3.loc[df3[variable]>upper_limit,variable]=upper_limit

# %%
replace_with_threshold(data_num,data_num.columns)

# %%
sns.countplot(df3['gender'])
plt.show()

# %%
sns.countplot(df3['lunch'])
plt.show()

# %%
df=df3.groupby('gender').mean(numeric_only = True)

# %%
df
# Out:
#         math_score  reading_score  writing_score     averge
# gender
# female   63.779923      72.640927      72.503378  69.569498
# male     68.728216      65.504149      63.356068  65.837483

# %%
df3.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'averge'],
#       dtype='object')

# %%
plt.bar('math_score',0.8,label='math_score')
plt.bar('reading_score',0.8,label='reading_score')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_num.head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
data_num.corr()
# Out:
#                math_score  reading_score  writing_score
# math_score       1.000000       0.817580       0.802642
# reading_score    0.817580       1.000000       0.954598
# writing_score    0.802642       0.954598       1.000000

# %%
sns.heatmap(data_num.corr())
plt.show()

# %%
sns.heatmap(data_num.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.pairplot(data_num)
plt.show()

# %%
sns.violinplot(data=data_num)
plt.show()

# %%
numeric_data = df4.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#                Member_number
# Member_number            1.0

# %%
numeric_data = df4.select_dtypes(include=['number'])
covariance_matrix = numeric_data.cov()
print(covariance_matrix)
# Out:
#                Member_number
# Member_number   1.330818e+06

# %%
numeric_data.skew()
# Out:
# Member_number   -0.007582
# dtype: float64

# %%
sns.distplot(df4['Member_number'])
# Out:
# <Axes: xlabel='Member_number', ylabel='Density'>

# %%
df4.columns
# Out:
# Index(['Member_number', 'Date', 'itemDescription'], dtype='object')

# %%
df4.groupby('Date').mean(numeric_only = True)
# Out:
#             Member_number
# Date
# 01-01-2014    2829.020833
# 01-01-2015    2771.750000
# 01-02-2014    3136.677419
# 01-02-2015    3272.983607
# 01-03-2014    3140.296296
# ...                   ...
# 31-07-2015    2819.634921
# 31-08-2014    3775.574468
# 31-08-2015    2468.531915
# 31-10-2014    3151.736842
# 31-10-2015    3047.695652
#
# [728 rows x 1 columns]

# %%
df4.groupby('Date').count()
# Out:
#             Member_number  itemDescription
# Date
# 01-01-2014             48               48
# 01-01-2015             48               48
# 01-02-2014             62               62
# 01-02-2015             61               61
# 01-03-2014             54               54
# ...                   ...              ...
# 31-07-2015             63               63
# 31-08-2014             47               47
# 31-08-2015             47               47
# 31-10-2014             57               57
# 31-10-2015             46               46
#
# [728 rows x 2 columns]

# %%
df4[df4['Member_number'] < 30].count()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
data_num=df4[asd]

# %%
data_num.head()
# Out:
#    Member_number
# 0           1808
# 1           2552
# 2           2300
# 3           1187
# 4           3037

# %%
sns.distplot(data_num['Member_number'])
plt.show()

# %%
sns.boxplot(df4['Member_number'])
plt.show()

# %%
q1 = df4['Member_number'].quantile(0.25)
q3 = df4['Member_number'].quantile(0.75)
iqr = q3 - q1

# %%
iqr
# Out:
# 2005.0

# %%
upper_limit=q3+(1.5*iqr)

# %%
upper_limit
# Out:
# 7014.5

# %%
lower_limit=q1-(1.5*iqr)

# %%
lower_limit
# Out:
# -1005.5

# %%
data_outlier=df4[df4['Member_number']<lower_limit]

# %%
data_num.drop(data_outlier.index)
# Out:
#        Member_number
# 0               1808
# 1               2552
# 2               2300
# 3               1187
# 4               3037
# ...              ...
# 38760           4471
# 38761           2022
# 38762           1097
# 38763           1510
# 38764           1521
#
# [38765 rows x 1 columns]

# %%
df4[df4['Member_number']>upper_limit]
# Out:
# Empty DataFrame
# Columns: [Member_number, Date, itemDescription]
# Index: []

# %%
df4['Member_number'].quantile(1.00)
# Out:
# 5000.0

# %%
df4['Member_number'].min()
# Out:
# 1000

# %%
df4['Member_number'].max()
# Out:
# 5000

# %%
df4['Member_number'].unique()
# Out:
# array([1808, 2552, 2300, ..., 3607, 4587, 2417])

# %%
data_num.columns
# Out:
# Index(['Member_number'], dtype='object')

# %%
def get_iqr(df, column_name, q1_range, q3_range):
    q1 = df[column_name].quantile(q1_range)
    q3 = df[column_name].quantile(q3_range)
    IQR = q3 - q1
    upper_fence = q3 + 1.5 * IQR
    lower_fence = q1 - 1.5 * IQR
    return IQR, upper_fence, lower_fence

# %%
def outlier_threshold(df,variable):
    q1=df[variable].quantile(0.25)
    q3=df[variable].quantile(0.75)
    iqr=q3-q1
    up_limit=q3+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %%
def replace_with_threshold(data,numeric_col):
    for variable in numeric_col:
        low_limit,upper_limit=outlier_threshold(data_num,variable)
        df4.loc[df4[variable]<low_limit,variable]=low_limit
        df4.loc[df4[variable]>upper_limit,variable]=upper_limit

# %%
replace_with_threshold(data_num,data_num.columns)

# %%
sns.countplot(df4['Member_number'])
plt.show()

# %%
df=df4.groupby('Member_number').mean(numeric_only = True)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [1000.0, 1001.0, 1002.0, 1003.0, 1004.0, 1005.0, 1006.0, 1008.0, 1009.0, 1010.0, 1011.0, 1012.0, 1013.0, 1014.0, 1015.0, 1016.0, 1017.0, 1018.0, 1019.0, 1020.0, 1021.0, 1022.0, 1023.0, 1024.0, 1025.0, 1026.0, 1027.0, 1028.0, 1029.0, 1031.0, 1032.0, 1033.0, 1034.0, 1035.0, 1036.0, 1037.0, 1038.0, 1039.0, 1040.0, 1041.0, 1042.0, 1043.0, 1044.0, 1045.0, 1046.0, 1047.0, 1048.0, 1049.0, 1050.0, 1051.0, 1052.0, 1053.0, 1054.0, 1055.0, 1056.0, 1057.0, 1058.0, 1059.0, 1061.0, 1062.0, 1063.0, 1064.0, 1065.0, 1066.0, 1067.0, 1068.0, 1069.0, 1070.0, 1071.0, 1072.0, 1073.0, 1074.0, 1075.0, 1076.0, 1077.0, 1078.0, 1079.0, 1080.0, 1081.0, 1082.0, 1083.0, 1084.0, 1085.0, 1086.0, 1087.0, 1088.0, 1089.0, 1090.0, 1092.0, 1093.0, 1094.0, 1095.0, 1096.0, 1097.0, 1098.0, 1099.0, 1100.0, 1101.0, 1102.0, 1103.0, ...]
#
# [3898 rows x 0 columns]

# %%
plt.bar('Member_number',0.8,label='Member_number')
plt.bar('Date',0.8,label='Date')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_num.head()
# Out:
#    Member_number
# 0           1808
# 1           2552
# 2           2300
# 3           1187
# 4           3037

# %%
data_num.corr()
# Out:
#                Member_number
# Member_number            1.0

# %%
sns.heatmap(data_num.corr())
plt.show()

# %%
sns.heatmap(data_num.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.pairplot(data_num)
plt.show()

# %%
sns.violinplot(data=data_num)
plt.show()
